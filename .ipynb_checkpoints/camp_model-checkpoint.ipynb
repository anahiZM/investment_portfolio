# %% [markdown]
# # CAMP model (capital asset pricing model) for stock market indices

# %% [markdown]
# **The necessary libraries are imported**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from scipy import stats
import yfinance as yf
from statsmodels.stats.stattools import durbin_watson

plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# If we need to install the yfinance library we enter: *!pip install yfinance*

# %% [markdown]
# **For this project we will use stock prices from the last 5 years to today (03/04/2024)**

# %% [markdown]
# **We bring the data from Yahoo Finance**

# %%
data = yf.Tickers('BBVA.MC, ^IBEX').history('5Y')['Close']
data = pd.DataFrame(data)
data.head()
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Ticker       BBVA.MC        ^IBEX
# Date
# 2019-03-04  4.061772  9259.799805
# 2019-03-05  4.039698  9258.200195
# 2019-03-06  4.089176  9296.700195
# 2019-03-07  3.972711  9249.900391
# 2019-03-08  3.909533  9129.299805

# %%
class Camp():
    "This class represents the CAMP model"
    def __init__(self, df, market, stock):
        self._df = df
        self._market = market
        self._stock = stock
        
        self._df_logreturn = self.log_returns()
        self._return_model = self.return_model()
        
    def log_returns(self):
        df_return = np.log(self._df/self._df.shift(1))
        df_return.dropna(inplace=True)
        return df_return
    
    def return_model(self):
        model = sm.OLS(self._df_logreturn[self._stock], self._df_logreturn[self._market]).fit()
        return model
    
    def return_summary(self):
        return self._return_model.summary()
    
    def return_resid(self):
        return self._return_model.resid

# %%
daily_return = Camp(data, "^IBEX", "BBVA.MC")
#daily_return.returns()

# %%
daily_return.return_summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                BBVA.MC   R-squared (uncentered):                   0.660
# Model:                            OLS   Adj. R-squared (uncentered):              0.659
# Method:                 Least Squares   F-statistic:                              2478.
# Date:                Tue, 05 Mar 2024   Prob (F-statistic):                   1.49e-301
# Time:                        00:05:33   Log-Likelihood:                          3653.6
# No. Observations:                1280   AIC:                                     -7305.
# Df Residuals:                    1279   BIC:                                     -7300.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# The 66% of the variability of the dependent variable is explained by the independent variable.

# %%
resids = daily_return.return_resid()
plt.plot(resids, 'b.')

# %% [markdown]
# In the graph it can be seen that the variance is not constant, there are relatively larger residuals, this is due to the presence of outliers.
#
# Having $d_L = 1.905$ and $d_U = 1.909$, since $D = 1.994 > d_U$ we conclude that there is no positive correlation between the errors, they are independent.

# %% [markdown]
# **Histogram + theoretical normal curve**

# %%
mu, sigma = stats.norm.fit(resids)

x_hat = np.linspace(min(resids), max(resids), num=100)
y_hat = stats.norm.pdf(x_hat, mu, sigma)

# Gráfico
fig, ax = plt.subplots(figsize=(7,4))
ax.plot(x_hat, y_hat, linewidth=2, label='normal')
ax.hist(x=resids, density=True, bins=70, color="#3182bd", alpha=0.5)
ax.plot(resids, np.full_like(resids, -0.01), '|k', markeredgewidth=1)
ax.set_title('Residual weight distribution')
ax.set_xlabel('Residual')
ax.set_ylabel('Probability density')
ax.legend();

# %% [markdown]
# **Gráfico Q-Q**

# %%
fig, ax = plt.subplots(figsize=(7,4))
sm.qqplot(
    resids,
    fit   = True,
    line  = 'q',
    alpha = 0.4,
    lw    = 2,
    ax    = ax
)
ax.set_title('Q-Q graph the residuals', fontsize = 10,
             fontweight = "bold")
ax.tick_params(labelsize = 7)

# %% [markdown]
# We see that the assumption of normality is respected, the points that do not fit could be due to outliers.
